# %%
import widgets

# %%
WeightsWidget = widgets.WeightsWidget()
WeightsWidget
# Out:
# WeightsWidget(children=(HBox(children=(Text(value='', description='Key:', layout=Layout(width='200px'), placeh…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Gintarich\source\repos\Gintarich\Widgets\Sections\.venv\Lib\site-packages\ipywidgets\widgets\widget.py:191, in CallbackDispatcher.__call__(self, *args, **kwargs)
#     189 for callback in self.callbacks:
#     190     try:
# --> 191         local_value = callback(*args, **kwargs)
#     192     except Exception as e:
#     193         ip = get_ipython()
#
# TypeError: WeightsWidget.save_data() takes 1 positional argument but 2 were given
