# %%
import widgets
import pathlib

# %%
widg = widgets.StructuralLoadWidget(    
    materials_path="widgets/assets/structural_load_materials.csv",
    state_path="state/structural_load_tables.json",
    )

# %%
widg
