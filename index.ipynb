# %%
import anywidget
import traitlets
from pathlib import Path

# %%
from widgets import Sections
sections = Sections()
sections

# %%
sections.selected_profile_data
# Out:
# {'profile': 'HEA220',
#  'type': 'HEA',
#  'standard': 'EN 10365:2017',
#  'series': 'HEA wide flange beams',
#  'shape': 'I',
#  'h': 210,
#  'b': 220,
#  't': None,
#  'tw': 7,
#  'tf': 11,
#  'r': 18,
#  'ro': None,
#  'ri': None,
#  'weight': 50.5,
#  'perimeter': 1.255,
#  'area': 6434,
#  'av': None,
#  'av_y': 4840,
#  'av_z': 2067,
#  'I_y': 54100000,
#  'I_z': 19550000,
#  'i_y': 91.7,
#  'i_z': 55.1,
#  'W_el_y': 515200,
#  'W_el_z': 177700,
#  'W_pl_y': 568500,
#  'W_pl_z': 270600,
#  'I_t': 280900,
#  'W_t': 25540,
#  'I_w': 189610000000,
#  'W_w': 17440000,
#  'buckling_curve': 1,
#  'section_class': 1,
#  'source_url': 'https://eurocodeapplied.com/design/en1993/ipe-hea-heb-hem-design-properties'}
